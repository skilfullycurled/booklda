# %% [markdown]
# ## SIX TOPICS

# %% [markdown]
# Topic 0: software code work source project time tool system making open mission group language team form
#
# Topic 1: network internet algorithm material concert file actor song archive object recording tape signal researcher work
#
# Topic 2: data design material human conflict computing world practice time approach visualization object building process make
#
# Topic 3: infrastructure gps action energy map venus infrastructural knowledge environmental social direction interaction artifact actor walk
#
# Topic 4: worker service labor center call woman issue expert voice controversy sound global sprint firm customer
#
# Topic 5: social technology medium system user movement study device communication scholar technological internet online emotion computer

# %% [markdown]
# Topic 0: software code work source project time tool system making open mission group language team form
#
# Topic 1: network internet algorithm material concert file actor song archive object recording tape signal researcher work
#
# Topic 2: data design material human conflict computing world practice time approach visualization object building process make
#
# Topic 3: infrastructure gps action energy map venus infrastructural knowledge environmental social direction interaction artifact actor walk
#
# Topic 4: worker service labor center call woman issue expert voice controversy sound global sprint firm customer
#
# Topic 5: social technology medium system user movement study device communication scholar technological internet online emotion computer

# %% [markdown]
# ## EIGHT TOPICS

# %% [markdown]
# Topic 0: data design material conflict building visualization time user materiality device specimen object coordination process system
#
# Topic 1: human algorithm action social interaction design artifact knowledge system emotion user actor practice air smart
#
# Topic 2: internet network computing computer human control world ubiquitous race surveillance italy nature life graph make
#
# Topic 3: worker service call labor center global voice sound firm customer accent consumer human computing industry
#
# Topic 4: project issue expert controversy energy sprint infrastructure woman public venus environmental question mapping data walk
#
# Topic 5: file concert material work song life archive infrastructural tape signal recording order knowledge piece infrastructure
#
# Topic 6: software code source work gps system mission project map language spreadsheet tool time group instruction
#
# Topic 7: social study work medium technology actor point relation movement form analysis science approach case question

# %% [markdown]
# Topic 0: data design material conflict building visualization time user materiality device specimen object coordination process system
#
# Topic 1: human algorithm action social interaction design artifact knowledge system emotion user actor practice air smart
#
# Topic 2: internet network computing computer human control world ubiquitous race surveillance italy nature life graph make
#
# Topic 3: worker service call labor center global voice sound firm customer accent consumer human computing industry
#
# Topic 4: project issue expert controversy energy sprint infrastructure woman public venus environmental question mapping data walk
#
# Topic 5: file concert material work song life archive infrastructural tape signal recording order knowledge piece infrastructure
#
# Topic 6: software code source work gps system mission project map language spreadsheet tool time group instruction
#
# Topic 7: social study work medium technology actor point relation movement form analysis science approach case question
